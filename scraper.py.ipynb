# %%
# Initial imports
import numpy as np
import pandas as pd 
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

import random
import urllib.request
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %%
base_url = "https://www.superherodb.com/characters/"
list_chars_cols = ['Name', 'Url']

url = base_url 
source_code = requests.get(url)
plain_text = source_code.text
soup = BeautifulSoup(plain_text, "html.parser")

# %%
list_of_supers = soup.findAll('li', {'class': 'char-li'})

# %%
len(list_of_supers)
# Out:
# 743

# %%
data = DataFrame(columns=list_chars_cols)
for l in list_of_supers:
    temp = DataFrame([[l.text, l.find('a').get('href')]])
    temp.columns = list_chars_cols
    data = data.append(temp, ignore_index=1)

# %%
data.head()
# Out:
#           Name                  Url
# 0      3-D Man     /3-d-man/10-226/
# 1       A-Bomb    /a-bomb/10-10060/
# 2   Abe Sapien  /abe-sapien/10-956/
# 3     Abin Sur   /abin-sur/10-1460/
# 4  Abomination   /abomination/10-1/

# %%
char_base_url = 'https://www.superherodb.com'
stats_list = ['Intelligence', 'Strength', 'Speed', 'Durability', 'Power', 'Combat', 
              'Url', 'Intelligence', 'Strength', 'Speed', 'Durability', 'Power', 
              'Combat', 'Full name', 'Alter Egos', 'Aliases', 'Place of birth', 
              'First appearance', 'Creator', 'Alignment', 'Gender', 'Race', 'Height', 
              'Weight', 'Eye color', 'Hair color', 'Occupation', 'Base', 'Team Affiliation', 'Relatives']
stat_data = DataFrame(columns=stats_list)
for index, row in data.iterrows():
    stat_map = {'Url': str(row['Url'])}
    char_url = char_base_url + str(row['Url'])
    source_code = requests.get(char_url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text, "html.parser")
    attrs = soup.findAll('div', {'class': 'gridbarholder'})
    personal = soup.findAll('table', {'class': 'table'})
    for a in attrs[:6]:
        stat_name = a.find('div', {'class': 'gridbarlabel'}).text
        stat_value = a.find('div', {'class': 'gridbarvalue'}).text
        stat_map[str(stat_name)] = stat_value
    for p in personal[:3]:
        trs = p.findAll('tr')
        for tr in trs:
            stat_map[str(tr.find('td').text.strip())] = str(tr.findAll('td')[1].text.strip())
    stat_map[str(personal[3].findAll('td')[0].text.strip())] = str(personal[3].findAll('td')[1].text.strip())
    stat_map[str(personal[3].findAll('td')[2].text.strip())] = str(personal[3].findAll('td')[3].text.strip())
    for key in stat_map.keys():
        stat_data.loc[index,key] = stat_map[key]

# %%
stat_data.head()
# Out:
#   Intelligence Strength Speed Durability Power Combat                  Url  \
# 0           80       35    45         35    25     55     /3-d-man/10-226/
# 1           75      100    20         80    25     65    /a-bomb/10-10060/
# 2           95       30    35         65   100     85  /abe-sapien/10-956/
# 3           80       90    55         65   100     65   /abin-sur/10-1460/
# 4           85       80    55         90    65     95   /abomination/10-1/
#
#   Intelligence Strength Speed    ...                   Race         Height  \
# 0           80       35    45    ...                      -  6'2 // 188 cm
# 1           75      100    20    ...                  Human  6'8 // 203 cm
# 2           95       30    35    ...          Icthyo Sapien  6'3 // 191 cm
# 3           80       90    55    ...                Ungaran  6'1 // 185 cm
# 4           85       80    55    ...      Human / Radiation  6'8 // 203 cm
#
#              Weight Eye color Hair color  \
# 0   200 lb // 90 kg     Brown       Grey
# 1  980 lb // 441 kg    Yellow    No Hair
# 2   145 lb // 65 kg      Blue    No Hair
# 3   200 lb // 90 kg      Blue    No Hair
# 4  980 lb // 441 kg     Green    No Hair
#
#                                           Occupation    Base  \
# 0                             Test pilot, adventurer       -
# 1  Musician, adventurer, author; formerly talk sh...       -
# 2                            Paranormal Investigator       -
# 3            Green Lantern, former history professor      Oa
# 4                                             Ex-Spy  Mobile
#
#                                     Team Affiliation  \
# 0    Agents of Atlas, Asgardians, Formerly: Avengers
# 1  Teen Brigade (Leader), Ultimate Fantastic Four...
# 2         Bureau for Paranormal Research and Defense
# 3  Legion of Super-Heroes, Formerly: Green Lanter...
# 4  Annihilators (Leader), Wrecking Crew, Masters ...
#
#                                            Relatives Skin color
# 0  Hal Chandler (brother), Peggy Clark (sister-in...        NaN
# 1  Marlo Chandler-Jones (wife); Polly (aunt); Mrs...        NaN
# 2                      Edith Howard (wife, deceased)       Blue
# 3  Amon Sur (son), Arin Sur (sister), Thaal Sines...        Red
# 4            Nadia Dornova Blonsky (wife, separated)        NaN
#
# [5 rows x 31 columns]

# %%
full_data = pd.merge(data, stat_data, left_index=True, right_index=True)

# %%
full_data.head()
# Out:
#           Name Intelligence Strength Speed Durability Power Combat  \
# 0      3-D Man           80       35    45         35    25     55
# 1       A-Bomb           75      100    20         80    25     65
# 2   Abe Sapien           95       30    35         65   100     85
# 3     Abin Sur           80       90    55         65   100     65
# 4  Abomination           85       80    55         90    65     95
#
#                  Url_y Intelligence Strength    ...                   Race  \
# 0     /3-d-man/10-226/           80       35    ...                      -
# 1    /a-bomb/10-10060/           75      100    ...                  Human
# 2  /abe-sapien/10-956/           95       30    ...          Icthyo Sapien
# 3   /abin-sur/10-1460/           80       90    ...                Ungaran
# 4   /abomination/10-1/           85       80    ...      Human / Radiation
#
#           Height            Weight Eye color Hair color  \
# 0  6'2 // 188 cm   200 lb // 90 kg     Brown       Grey
# 1  6'8 // 203 cm  980 lb // 441 kg    Yellow    No Hair
# 2  6'3 // 191 cm   145 lb // 65 kg      Blue    No Hair
# 3  6'1 // 185 cm   200 lb // 90 kg      Blue    No Hair
# 4  6'8 // 203 cm  980 lb // 441 kg     Green    No Hair
#
#                                           Occupation    Base  \
# 0                             Test pilot, adventurer       -
# 1  Musician, adventurer, author; formerly talk sh...       -
# 2                            Paranormal Investigator       -
# 3            Green Lantern, former history professor      Oa
# 4                                             Ex-Spy  Mobile
#
#                                     Team Affiliation  \
# 0    Agents of Atlas, Asgardians, Formerly: Avengers
# 1  Teen Brigade (Leader), Ultimate Fantastic Four...
# 2         Bureau for Paranormal Research and Defense
# 3  Legion of Super-Heroes, Formerly: Green Lanter...
# 4  Annihilators (Leader), Wrecking Crew, Masters ...
#
#                                            Relatives Skin color
# 0  Hal Chandler (brother), Peggy Clark (sister-in...        NaN
# 1  Marlo Chandler-Jones (wife); Polly (aunt); Mrs...        NaN
# 2                      Edith Howard (wife, deceased)       Blue
# 3  Amon Sur (son), Arin Sur (sister), Thaal Sines...        Red
# 4            Nadia Dornova Blonsky (wife, separated)        NaN
#
# [5 rows x 32 columns]

# %%
full_data.drop('Url_x', 1,  inplace=True)
f = full_data.rename(index=str, columns={"Url_y": "Url"})

# %%
full_data.head()
# Out:
#           Name Intelligence Strength Speed Durability Power Combat  \
# 0      3-D Man           80       35    45         35    25     55
# 1       A-Bomb           75      100    20         80    25     65
# 2   Abe Sapien           95       30    35         65   100     85
# 3     Abin Sur           80       90    55         65   100     65
# 4  Abomination           85       80    55         90    65     95
#
#                  Url_y Intelligence Strength    ...                   Race  \
# 0     /3-d-man/10-226/           80       35    ...                      -
# 1    /a-bomb/10-10060/           75      100    ...                  Human
# 2  /abe-sapien/10-956/           95       30    ...          Icthyo Sapien
# 3   /abin-sur/10-1460/           80       90    ...                Ungaran
# 4   /abomination/10-1/           85       80    ...      Human / Radiation
#
#           Height            Weight Eye color Hair color  \
# 0  6'2 // 188 cm   200 lb // 90 kg     Brown       Grey
# 1  6'8 // 203 cm  980 lb // 441 kg    Yellow    No Hair
# 2  6'3 // 191 cm   145 lb // 65 kg      Blue    No Hair
# 3  6'1 // 185 cm   200 lb // 90 kg      Blue    No Hair
# 4  6'8 // 203 cm  980 lb // 441 kg     Green    No Hair
#
#                                           Occupation    Base  \
# 0                             Test pilot, adventurer       -
# 1  Musician, adventurer, author; formerly talk sh...       -
# 2                            Paranormal Investigator       -
# 3            Green Lantern, former history professor      Oa
# 4                                             Ex-Spy  Mobile
#
#                                     Team Affiliation  \
# 0    Agents of Atlas, Asgardians, Formerly: Avengers
# 1  Teen Brigade (Leader), Ultimate Fantastic Four...
# 2         Bureau for Paranormal Research and Defense
# 3  Legion of Super-Heroes, Formerly: Green Lanter...
# 4  Annihilators (Leader), Wrecking Crew, Masters ...
#
#                                            Relatives Skin color
# 0  Hal Chandler (brother), Peggy Clark (sister-in...        NaN
# 1  Marlo Chandler-Jones (wife); Polly (aunt); Mrs...        NaN
# 2                      Edith Howard (wife, deceased)       Blue
# 3  Amon Sur (son), Arin Sur (sister), Thaal Sines...        Red
# 4            Nadia Dornova Blonsky (wife, separated)        NaN
#
# [5 rows x 32 columns]

# %%
full_data.to_csv('SuperheroDataset.csv', encoding='utf-8')
